# %%
import pandas

# %%
import requests

# %%
alto = 'http://altoadvisory.pl/en/about-us/'
r=requests.get(alto)
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-GB">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-GB">
# <![endif]-->
# <!--[if !(IE 7) & !(IE 8)]><!-->
# <html lang="en-GB" class="">
# <!--<![endif]-->
# <head>
# 	<meta charset="UTF-8" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=no" />
# 	<meta name="description" content="ALTO - Więcej niż doradcy" />
# 	<meta name="keywords" content="ALTO" />
# 	<meta name="og:title" content="ALTO - Więcej niż doradcy" />
# 	<meta name="og:description" content="ALTO - Więcej niż doradcy" />
# 	<meta name="author" content="msolowski Marcin Sołowski - msolowski.pl" />
# 	<meta name="google-site-verification" content="R0xEx6RfigvaMrs5CmgvDOHonL7cLmyJ5vRMPYAjqMA" />
# 	<title>ALTO &#8211; More than advisors | About us</title>
# 	<link rel="icon" type="image/png" href="http://altoadvisory.pl/wp-content/themes/alto/favicon.png" />
# 	<!--[if lt IE 9]>
# 	<script type="text/javascript" src="http://altoadvisory.pl/wp-content/themes/alto/js/html5-3.7.min.js"></script>
# 	<![endif]-->
# 	<script type="text/javascript">
# 		window.paceOptions = {
# 			minTime: 50,
# 			restartOnPushState: false,
# 			restartOnRequestAfter: false
# 		};
# 	</script>
# 	<link rel='dns-prefetch' href='//www.google.com' />
# <link rel='dns-prefetch' href='//cdnjs.cloudflare.com' />
# <link rel='dns-prefetch' href='//s.w.org' />
# 		<script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/altoadvisory.pl\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.8"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link rel='stylesheet' id='contact-form-7-css'  href='http://altoadvisory.pl/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.0.3' type='text/css' media='all' />
# <link rel='stylesheet' id='wordpress-gdpr-css'  href='http://altoadvisory.pl/wp-content/plugins/wordpress-gdpr/public/css/wordpress-gdpr-public.css?ver=1.4.0.2' type='text/css' media='all' />
# <link rel='stylesheet' id='font-awesome-css'  href='https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css?ver=4.7.0' type='text/css' media='all' />
# <link rel='stylesheet' id='style-css'  href='http://altoadvisory.pl/wp-content/themes/alto/style.css' type='text/css' media='all' />
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/themes/alto/js/jquery-2.1.4.min.js'></script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/themes/alto/js/pace-1.0.mod.js'></script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/themes/alto/js/cbpAnimatedHeader-1.0.1.mod.min.js'></script>
# <link rel='https://api.w.org/' href='http://altoadvisory.pl/wp-json/' />
# <link rel="EditURI" type="application/rsd+xml" title="RSD" href="http://altoadvisory.pl/xmlrpc.php?rsd" />
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="http://altoadvisory.pl/wp-includes/wlwmanifest.xml" />
# <link rel="canonical" href="http://altoadvisory.pl/en/about-us/" />
# <link rel='shortlink' href='http://altoadvisory.pl/?p=100' />
# <link rel="alternate" type="application/json+oembed" href="http://altoadvisory.pl/wp-json/oembed/1.0/embed?url=http%3A%2F%2Faltoadvisory.pl%2Fen%2Fabout-us%2F" />
# <link rel="alternate" type="text/xml+oembed" href="http://altoadvisory.pl/wp-json/oembed/1.0/embed?url=http%3A%2F%2Faltoadvisory.pl%2Fen%2Fabout-us%2F&#038;format=xml" />
# <link rel="alternate" href="http://altoadvisory.pl/o-nas/" hreflang="pl" />
# <link rel="alternate" href="http://altoadvisory.pl/en/about-us/" hreflang="en" />
# </head>
# <body class="page-template page-template-o_nas_template page-template-o_nas_template-php page page-id-100">
# 	<div id="menu_small" class="menu_small_scale">
# 		<nav id="menu_small_content">
# 			<div class="menu-menu-en-container"><ul id="menu-menu-en" class="menu"><li id="menu-item-127" class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-100 current_page_item menu-item-127"><a href="http://altoadvisory.pl/en/about-us/">About us</a></li>
# <li id="menu-item-126" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-126"><a href="http://altoadvisory.pl/en/services/">Services</a>
# <ul class="sub-menu">
# 	<li id="menu-item-395" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-395"><a href="http://altoadvisory.pl/en/uslugi/tax-en/">Tax</a></li>
# 	<li id="menu-item-393" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-393"><a href="http://altoadvisory.pl/en/uslugi/legal-en/">Legal</a></li>
# 	<li id="menu-item-392" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-392"><a href="http://altoadvisory.pl/en/uslugi/accounting-en/">Accounting</a></li>
# 	<li id="menu-item-394" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-394"><a href="http://altoadvisory.pl/en/uslugi/start-up-more-en/">Start-up &#038; more</a></li>
# </ul>
# </li>
# <li id="menu-item-964" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-964"><a href="http://altoadvisory.pl/en/team/">Team</a>
# <ul class="sub-menu">
# 	<li id="menu-item-1203" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1203"><a href="http://altoadvisory.pl/en/zespol/tax-en/">Tax</a></li>
# 	<li id="menu-item-1205" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1205"><a href="http://altoadvisory.pl/en/zespol/legal-en/">Legal</a></li>
# 	<li id="menu-item-1204" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1204"><a href="http://altoadvisory.pl/en/zespol/accounting-en/">Accounting</a></li>
# 	<li id="menu-item-1206" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1206"><a href="http://altoadvisory.pl/en/zespol/start-up-en/">Start-up</a></li>
# </ul>
# </li>
# <li id="menu-item-124" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-124"><a href="http://altoadvisory.pl/en/news/">News</a>
# <ul class="sub-menu">
# 	<li id="menu-item-1209" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1209"><a href="http://altoadvisory.pl/en/aktualnosci/comments/">Comments</a></li>
# 	<li id="menu-item-1207" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1207"><a href="http://altoadvisory.pl/en/aktualnosci/articles/">Articles</a></li>
# 	<li id="menu-item-1208" class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1208"><a href="http://altoadvisory.pl/en/aktualnosci/career/">Career</a></li>
# </ul>
# </li>
# <li id="menu-item-123" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-123"><a href="http://altoadvisory.pl/en/contact/">Contact</a></li>
# </ul></div>		</nav>
# 		<div id="menu_small_langs">
# 			<div class="languages_list">
# 				<div class="menu-languages-all-container"><ul id="menu-languages-all" class="menu"><li id="menu-item-128-pl" class="lang-item lang-item-2 lang-item-pl lang-item-first menu-item menu-item-type-custom menu-item-object-custom menu-item-128-pl"><a href="http://altoadvisory.pl/o-nas/" hreflang="pl-PL" lang="pl-PL"><img src="data:image/png;base64,..." title="Polski" alt="Polski" /></a></li>
# <li id="menu-item-128-en" class="lang-item lang-item-5 lang-item-en current-lang menu-item menu-item-type-custom menu-item-object-custom menu-item-128-en"><a><img src="data:image/png;base64,..." title="English" alt="English" /></a></li>
# </ul></div>			</div>
# 		</div>
# 	</div>
# 	<script type="text/javascript">
# 		$(function()
# 		{
# 			$('#header_contener_navigation_menu_small').on('click', toggleOverlay);
#
# 			function toggleOverlay()
# 			{
# 				$('#menu_small').toggleClass('open');
#
#
#
#
#
#
# 				$('body').toggleClass('hide');
# 				$('#header_contener_navigation_menu_small').toggleClass('open');
# 				$('#header').toggleClass('open_menu');
# 				$('#header_contener_logo').toggleClass('open_menu');
# 				if($('#header').hasClass('header_scroll'))
# 				{
# 					$('#header').addClass('close_menu');
# 				}
# 				else
# 				{
# 					$('#header').removeClass('close_menu');
# 				}
# 				return false;
# 			}
# 		});
# 	</script>
# 	<div id="all_page"><!-- #all_page -->
# 		<header id="header" class="not_home"><!-- #header -->
# 			<div id="header_contener">
# 				<a id="header_contener_logo" href="http://altoadvisory.pl/en/" title="Go to main page">
# 					<h1>
# 						<svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 							 width="93.168px" height="23.836px" viewBox="0 0 93.168 23.836" enable-background="new 0 0 93.168 23.836" xml:space="preserve">
# 						<title>ALTO - More than advisors</title>
# 						<polygon fill="#FFFFFF" points="27,0.836 27,23.836 41,23.836 41,19.574 32.39,19.574 32.39,0.836 "/>
# 						<polygon fill="#FFFFFF" points="47,0.836 47,5.067 53.373,5.067 53.373,23.836 58.627,23.836 58.627,5.067 65,5.067
# 							65,0.836 "/>
# 						<path fill="#FFFFFF" d="M7.65,0.272L5.207,6.083c0.027,0.083,0.218,0.679,0.246,0.76
# 							c0.185,0.55,0.346,1.027,0.483,1.433l2.121,6.387H1.549L0,18.345h9.291l1.361,4.066c0.116,0.342,0.325,0.622,0.625,0.841
# 							c0.3,0.219,0.684,0.328,1.148,0.328h4.146L7.65,0.272z"/>
# 						<path fill="#FFFFFF" d="M87.678,18.746c-0.08,0.034-0.156,0.072-0.238,0.104
# 							c-0.787,0.294-1.676,0.451-2.654,0.488c-0.123,0.005-0.242,0.016-0.367,0.016c-0.008,0-0.014-0.001-0.021-0.001
# 							c-0.011,0-0.021,0.001-0.031,0.001c-1.033,0-1.955-0.168-2.762-0.504s-1.488-0.824-2.043-1.465
# 							c-0.553-0.641-0.979-1.422-1.273-2.346c-0.295-0.922-0.443-1.966-0.443-3.129c0-1.152,0.148-2.19,0.443-3.113
# 							c0.295-0.924,0.721-1.705,1.273-2.345c0.555-0.64,1.236-1.132,2.043-1.473c0.807-0.342,1.729-0.512,2.762-0.512
# 							c0.007,0,0.014,0,0.021,0c0.011,0,0.021-0.001,0.032-0.001c0.158,0,0.313,0.005,0.465,0.014c0.941,0.044,1.794,0.209,2.557,0.499
# 							c0.899,0.341,1.661,0.833,2.282,1.473c0.622,0.64,1.099,1.421,1.431,2.345c0.02,0.055,0.033,0.115,0.053,0.171l1.963-5.444
# 							c-0.025-0.027-0.051-0.055-0.076-0.082c-1.045-1.067-2.303-1.907-3.775-2.521C87.845,0.307,86.211,0,84.418,0
# 							c-1.795,0-3.43,0.304-4.907,0.912c-1.478,0.608-2.741,1.446-3.791,2.513c-1.05,1.068-1.862,2.327-2.438,3.778
# 							s-0.862,3.02-0.862,4.706s0.287,3.255,0.862,4.707s1.388,2.714,2.438,3.786s2.313,1.912,3.791,2.521
# 							c1.478,0.607,3.112,0.912,4.907,0.912c0.496,0,0.979-0.025,1.449-0.072L87.678,18.746z"/>
# 						</svg>
# 					</h1>
# 				</a>
# 				<div id="header_contener_navigation">
# 					<div id="header_contener_navigation_menu_small">
# 						<span></span>
# 						<span></span>
# 						<span></span>
# 						<span></span>
# 						<span></span>
# 					</div>
# 					<div class="languages_list">
# 						<div class="menu-languages-all-container"><ul id="menu-languages-all-1" class="menu"><li class="lang-item lang-item-2 lang-item-pl lang-item-first menu-item menu-item-type-custom menu-item-object-custom menu-item-128-pl"><a href="http://altoadvisory.pl/o-nas/" hreflang="pl-PL" lang="pl-PL"><img src="data:image/png;base64,..." title="Polski" alt="Polski" /></a></li>
# <li class="lang-item lang-item-5 lang-item-en current-lang menu-item menu-item-type-custom menu-item-object-custom menu-item-128-en"><a><img src="data:image/png;base64,..." title="English" alt="English" /></a></li>
# </ul></div>					</div>
# 					<nav id="header_contener_navigation_menu">
# 						<div class="menu-menu-en-container"><ul id="menu-menu-en-1" class="menu"><li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-100 current_page_item menu-item-127"><a href="http://altoadvisory.pl/en/about-us/">About us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-126"><a href="http://altoadvisory.pl/en/services/">Services</a>
# <ul class="sub-menu">
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-395"><a href="http://altoadvisory.pl/en/uslugi/tax-en/">Tax</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-393"><a href="http://altoadvisory.pl/en/uslugi/legal-en/">Legal</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-392"><a href="http://altoadvisory.pl/en/uslugi/accounting-en/">Accounting</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_usluga menu-item-394"><a href="http://altoadvisory.pl/en/uslugi/start-up-more-en/">Start-up &#038; more</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-964"><a href="http://altoadvisory.pl/en/team/">Team</a>
# <ul class="sub-menu">
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1203"><a href="http://altoadvisory.pl/en/zespol/tax-en/">Tax</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1205"><a href="http://altoadvisory.pl/en/zespol/legal-en/">Legal</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1204"><a href="http://altoadvisory.pl/en/zespol/accounting-en/">Accounting</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_zespol menu-item-1206"><a href="http://altoadvisory.pl/en/zespol/start-up-en/">Start-up</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-124"><a href="http://altoadvisory.pl/en/news/">News</a>
# <ul class="sub-menu">
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1209"><a href="http://altoadvisory.pl/en/aktualnosci/comments/">Comments</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1207"><a href="http://altoadvisory.pl/en/aktualnosci/articles/">Articles</a></li>
# 	<li class="menu-item menu-item-type-taxonomy menu-item-object-kategoria_aktualnosc menu-item-1208"><a href="http://altoadvisory.pl/en/aktualnosci/career/">Career</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-123"><a href="http://altoadvisory.pl/en/contact/">Contact</a></li>
# </ul></div>					</nav>
# 				</div>
# 			</div>
# 		</header>
# 		<div id="main_page" class=""><!-- #main_page -->
# <div id="main_page_center" class="o_nas">
# 	<div id="o_nas_template">
# 		<div id="o_nas_template_left" class="parallax_up">
# 			<div id="o_nas_template_left_text">
# 				<p>Currently, we are one of the fastest growing advisory firms in Poland.</p>
# <p>We can trace our origins back to 2011 when the firm started operations under its previous name, FL Tax. With a focus on establishing a strong position in the market and expanding competence in the area of tax advisory services, we developed further business lines — legal, investment, and strategic consultancy services, and also outsourcing of the accounting and payroll function. The unification of our business lines under a common brand in 2018 and their further development under the name ALTO became the symbol of our growing position and business maturity.</p>
# <p>Today, ALTO is a firm where entrepreneurs and investors can find the support necessary for effective operation, irrespective of the industry or project phase. We work with both start-up companies and large domestic and international organizations.</p>
# <p>We can also offer experience, expertise, and connections which are essential for carrying out international operations. Our firm is affiliated with the Alliott Group, an international association of independent accounting, law, and consulting firms. The association comprises 170 member firms doing business in some 70 countries. ALTO is the only Polish member of this organization that provides tax advisory services. Being affiliated with Alliot Group gives us the competence to engage advisors representing various jurisdictions. We are also active members of the International Bar Association and the International Fiscal Association.</p>
# 			</div>
# 		</div>
# 		<div id="o_nas_template_right" style="background-image: url(http://altoadvisory.pl/wp-content/uploads/2017/09/O-nas_Fotolia_111398650_Subscription_Monthly_XL-1080x720.jpg);">
# 			<div id="o_nas_template_right_background" class="parallax_down"></div>
# 		</div>
# 	</div>
# </div>
# <script type="text/javascript">
# 	$(function()
# 	{
# 		$(window).on('load', function()
# 		{
# 			enquire.register('screen and (min-width: 961px)', function()
# 			{
# 				var text_height = $('#o_nas_template_left_text').outerHeight();
# 				$('#o_nas_template_right').outerHeight(text_height);
# 			});
# 		});
#
# 		if(!isMobile.any())
# 		{
# 			var parallax_up = document.querySelectorAll('.parallax_up'),
# 			parallax_up_speed = -0.5;
# 			var parallax_down = document.querySelectorAll('.parallax_down'),
# 			parallax_down_speed = 0.5;
#
# 			parallax();
# 			window.onscroll = parallax;
#
# 			function parallax()
# 			{
# 				[].slice.call(parallax_up).forEach(function(el, i)
# 				{
# 					var windowYOffset = window.pageYOffset,
# 					elBackgrounPos = '0%' + (windowYOffset * parallax_up_speed) + 'px';
# 					el.style.backgroundPosition = elBackgrounPos;
# 				});
#
# 				[].slice.call(parallax_down).forEach(function(el, i)
# 				{
# 					var windowYOffset = window.pageYOffset,
# 					elBackgrounPos = '100%' + (windowYOffset * parallax_down_speed) + 'px';
# 					el.style.backgroundPosition = elBackgrounPos;
# 				});
# 			};
# 		}
# 	});
# </script>
#
# 		</div><!-- #main_page -->
# 		<footer id="footer" class="">
# 			<div id="footer_contener">
# 				<div id="footer_contener_logo">
# 					<a href="http://altoadvisory.pl/en/" title="Go to main page" id="footer_contener_logo_btn">
# 						<svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 							 width="93.168px" height="23.836px" viewBox="0 0 93.168 23.836" enable-background="new 0 0 93.168 23.836" xml:space="preserve">
# 						<title>ALTO - More than advisors</title>
# 						<polygon fill="#ffffff" points="27,0.836 27,23.836 41,23.836 41,19.574 32.39,19.574 32.39,0.836 "/>
# 						<polygon fill="#ffffff" points="47,0.836 47,5.067 53.373,5.067 53.373,23.836 58.627,23.836 58.627,5.067 65,5.067
# 							65,0.836 "/>
# 						<path fill="#ffffff" d="M7.65,0.272L5.207,6.083c0.027,0.083,0.218,0.679,0.246,0.76
# 							c0.185,0.55,0.346,1.027,0.483,1.433l2.121,6.387H1.549L0,18.345h9.291l1.361,4.066c0.116,0.342,0.325,0.622,0.625,0.841
# 							c0.3,0.219,0.684,0.328,1.148,0.328h4.146L7.65,0.272z"/>
# 						<path fill="#ffffff" d="M87.678,18.746c-0.08,0.034-0.156,0.072-0.238,0.104
# 							c-0.787,0.294-1.676,0.451-2.654,0.488c-0.123,0.005-0.242,0.016-0.367,0.016c-0.008,0-0.014-0.001-0.021-0.001
# 							c-0.011,0-0.021,0.001-0.031,0.001c-1.033,0-1.955-0.168-2.762-0.504s-1.488-0.824-2.043-1.465
# 							c-0.553-0.641-0.979-1.422-1.273-2.346c-0.295-0.922-0.443-1.966-0.443-3.129c0-1.152,0.148-2.19,0.443-3.113
# 							c0.295-0.924,0.721-1.705,1.273-2.345c0.555-0.64,1.236-1.132,2.043-1.473c0.807-0.342,1.729-0.512,2.762-0.512
# 							c0.007,0,0.014,0,0.021,0c0.011,0,0.021-0.001,0.032-0.001c0.158,0,0.313,0.005,0.465,0.014c0.941,0.044,1.794,0.209,2.557,0.499
# 							c0.899,0.341,1.661,0.833,2.282,1.473c0.622,0.64,1.099,1.421,1.431,2.345c0.02,0.055,0.033,0.115,0.053,0.171l1.963-5.444
# 							c-0.025-0.027-0.051-0.055-0.076-0.082c-1.045-1.067-2.303-1.907-3.775-2.521C87.845,0.307,86.211,0,84.418,0
# 							c-1.795,0-3.43,0.304-4.907,0.912c-1.478,0.608-2.741,1.446-3.791,2.513c-1.05,1.068-1.862,2.327-2.438,3.778
# 							s-0.862,3.02-0.862,4.706s0.287,3.255,0.862,4.707s1.388,2.714,2.438,3.786s2.313,1.912,3.791,2.521
# 							c1.478,0.607,3.112,0.912,4.907,0.912c0.496,0,0.979-0.025,1.449-0.072L87.678,18.746z"/>
# 						</svg>
# 					</a>
# 				</div>
# 				<div id="footer_contener_left_right">
# 					<div id="footer_contener_left">
# 						<div id="footer_contener_left_info">
# 							<div id="footer_contener_left_info_left">
# 								<p>
# 									Bitwy Warszawskiej								</p>
# 								<p>
# 									Business Center								</p>
# 							</div>
# 							<div id="footer_contener_left_info_center">
# 								<p>
# 									ul. Bitwy Warszawskiej 1920 r. 7								</p>
# 								<p>
# 									02-366 Warszawa								</p>
# 							</div>
# 							<div id="footer_contener_left_info_right">
# 								<p>
# 									tel.: +48 22 652 27 51								</p>
# 								<p>
# 									<a href="mailto:alto@altoadvisory.pl">e-mail: alto@altoadvisory.pl</a>
# 								</p>
# 							</div>
# 						</div>
# 						<a href="http://altoadvisory.pl/contact/" title="Go to contact" id="footer_contener_left_contact_btn">
# 							<span>Contact us</span>
# 						</a>
# 					</div>
# 					<div id="footer_contener_right">
# 						<div id="footer_contener_right_name">
# 							Membership:
# 						</div>
# 						<div id="footer_contener_right_company">
# 							<div id="footer_contener_right_company_left">
# 								<img src="http://altoadvisory.pl/wp-content/themes/alto/img/logo_iba.png" alt="">
# 							</div>
# 							<div id="footer_contener_right_company_center">
# 								<img src="http://altoadvisory.pl/wp-content/themes/alto/img/logo_alliott.png" alt="">
# 							</div>
# 							<div id="footer_contener_right_company_right">
# 								<img src="http://altoadvisory.pl/wp-content/themes/alto/img/logo_ifa.png" alt="">
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 				<div id="footer_contener_bottom">
# 					<div id="footer_contener_bottom_left">
# 						copyright 2018 ALTO
# 					</div>
# 					<div id="footer_contener_bottom_center">
# 						All rights reserved					</div>
# 					<div id="footer_contener_bottom_right">
# 						<a href="http://altoadvisory.pl/en/newsletter-en/" title="Go to Newsletter">Newsletter</a>
# 						| <a href="http://altoadvisory.pl/en/privacy-policy/" title="Go to Privacy Policy">Privacy Policy</a>
# 						| design by <a target="_blank" href="http://logotomia.com.pl/" title="Go to logotomia.com.pl">Logotomia</a>
# 					</div>
# 				</div>
# 			</div>
# 			<div id="footer_top">
# 				<svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
# 					 width="18px" height="10.388px" viewBox="0 0 18 10.388" enable-background="new 0 0 18 10.388" xml:space="preserve">
# 				<rect x="-1.172" y="4.215" transform="matrix(0.7071 -0.7071 0.7071 0.7071 -2.152 5.1935)" fill="#00A3E0" width="12.73" height="1.958"/>
# 				<rect x="6.444" y="4.213" transform="matrix(0.7071 0.7071 -0.7071 0.7071 7.4227 -7.5359)" fill="#00A3E0" width="12.728" height="1.958"/>
# 				</svg>
# 			</div>
# 		</footer>
# 		<script type="text/javascript">
# 			$(function()
# 			{
# 				$(window).on('scroll', function()
# 				{
# 					if($(this).scrollTop() > 90)
# 					{
# 						$('#footer_top').addClass('showed');
# 					}
# 					else
# 					{
# 						$('#footer_top').removeClass('showed');
# 					}
# 				});
#
# 				$(window).on('load', function()
# 				{
# 					if($(this).scrollTop() > 90)
# 					{
# 						$('#footer_top').addClass('showed');
# 					}
# 					else
# 					{
# 						$('#footer_top').removeClass('showed');
# 					}
#
# 					/* $('#menu_mobile_content').mCustomScrollbar(
# 					{
# 						theme: 'custom_theme',
# 						advanced: { updateOnContentResize: true }
# 					}); */
# 				});
#
# 				$('#footer_top').on('click', function()
# 				{
# 					$('html, body').animate(
# 					{
# 						scrollTop: 0
# 					}, 500);
# 					return false;
# 				});
# 			});
# 		</script>
# 	</div><!-- #all_page -->
# 	        <div class="wordpress-gdpr-popup wordpress-gdpr-popup-full-width wordpress-gdpr-popup-bottom"
#             style="background-color: #0d0d0d; color: #FFFFFF;">
#                                         <div class="wordpress-gdpr-popup-container">
#                             <a href="#" id="wordpress-gdpr-popup-close" class="wordpress-gdpr-popup-close" style="background-color: #000000;">
#                     <i style="color: #FFFFFF;" class="fa fa-times"></i>
#                 </a>
#                 <div class="wordpress-gdpr-popup-text"><p>Website uses cookies files for the purpose of providing services and in accordance with the <a href="http://altoadvisory.pl/en/privacy-policy/">Privacy Policy</a>.</p>
# <p>You can specify the conditions for their storage or access using the below settings.</p>
# </div>
#                 <div class="wordpress-gdpr-popup-actions">
#
#                                             <a href="#" class="wordpress-gdpr-popup-agree">I accept</a>
#
#                                             <a href="#" class="wordpress-gdpr-popup-decline">I decline</a>
#
#                                             <a href="http://altoadvisory.pl/en/privacy-center/" class="wordpress-gdpr-popup-privacy-center">Privacy Center</a>
#
#                                             <a href="http://altoadvisory.pl/en/privacy-settings/" class="wordpress-gdpr-popup-privacy-settings-text">Privacy Settings</a>
#
#                                             <a href="http://altoadvisory.pl/en/privacy-policy/" class="wordpress-gdpr-popup-read-more">Cookies Policy</a>
#                                     </div>
#             </div>
#         </div>
#                 <script type='text/javascript'>
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"http:\/\/altoadvisory.pl\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"recaptcha":{"messages":{"empty":"Please verify that you are not a robot."}}};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.0.3'></script>
# <script type='text/javascript'>
# /* <![CDATA[ */
# var gdpr_options = {"ajaxURL":"http:\/\/altoadvisory.pl\/wp-admin\/admin-ajax.php","cookieLifetime":"30","geoIP":"0","popupExcludePages":"","checks":["wordpress_gdpr_cookies_allowed","wordpress_gdpr_analytics_allowed","wordpress_gdpr_privacy_policy_accepted"]};
# /* ]]> */
# </script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/plugins/wordpress-gdpr/public/js/wordpress-gdpr-public.js?ver=1.4.0.2'></script>
# <script type='text/javascript'>
# var renderInvisibleReCaptcha = function() {
#
#     for (var i = 0; i < document.forms.length; ++i) {
#         var form = document.forms[i];
#         var holder = form.querySelector('.inv-recaptcha-holder');
#
#         if (null === holder) continue;
# 		holder.innerHTML = '';
#
#          (function(frm){
# 			var cf7SubmitElm = frm.querySelector('.wpcf7-submit');
#             var holderId = grecaptcha.render(holder,{
#                 'sitekey': '6Lf97FoUAAAAAHTkNj3EabTURcpaKan3BnKMftpX', 'size': 'invisible', 'badge' : 'bottomleft',
#                 'callback' : function (recaptchaToken) {
# 					if((null !== cf7SubmitElm) && (typeof jQuery != 'undefined')){jQuery(frm).submit();grecaptcha.reset(holderId);return;}
# 					 HTMLFormElement.prototype.submit.call(frm);
#                 },
#                 'expired-callback' : function(){grecaptcha.reset(holderId);}
#             });
#
# 			if(null !== cf7SubmitElm && (typeof jQuery != 'undefined') ){
# 				jQuery(cf7SubmitElm).off('click').on('click', function(clickEvt){
# 					clickEvt.preventDefault();
# 					grecaptcha.execute(holderId);
# 				});
# 			}
# 			else
# 			{
# 				frm.onsubmit = function (evt){evt.preventDefault();grecaptcha.execute(holderId);};
# 			}
#
#
#         })(form);
#     }
# };
# </script>
# <script type='text/javascript' async defer src='https://www.google.com/recaptcha/api.js?onload=renderInvisibleReCaptcha&#038;render=explicit'></script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/themes/alto/js/isMobile.min.js'></script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-content/themes/alto/js/enquire-2.1.6.min.js'></script>
# <script type='text/javascript' src='http://altoadvisory.pl/wp-includes/js/wp-embed.min.js?ver=4.9.8'></script>
# </body>
# </html>

# %%
import urllib
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = alto
html = urlopen(url).read()
soup = BeautifulSoup(html)

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# ALTO – More than advisors | About us
# About us
# Services
# Tax
# Legal
# Accounting
# Start-up & more
# Team
# Tax
# Legal
# Accounting
# Start-up
# News
# Comments
# Articles
# Career
# Contact
# ALTO - More than advisors
# About us
# Services
# Tax
# Legal
# Accounting
# Start-up & more
# Team
# Tax
# Legal
# Accounting
# Start-up
# News
# Comments
# Articles
# Career
# Contact
# Currently, we are one of the fastest growing advisory firms in Poland.
# We can trace our origins back to 2011 when the firm started operations under its previous name, FL Tax. With a focus on establishing a strong position in the market and expanding competence in the area of tax advisory services, we developed further business lines — legal, investment, and strategic consultancy services, and also outsourcing of the accounting and payroll function. The unification of our business lines under a common brand in 2018 and their further development under the name ALTO became the symbol of our growing position and business maturity.
# Today, ALTO is a firm where entrepreneurs and investors can find the support necessary for effective operation, irrespective of the industry or project phase. We work with both start-up companies and large domestic and international organizations.
# We can also offer experience, expertise, and connections which are essential for carrying out international operations. Our firm is affiliated with the Alliott Group, an international association of independent accounting, law, and consulting firms. The association comprises 170 member firms doing business in some 70 countries. ALTO is the only Polish member of this organization that provides tax advisory services. Being affiliated with Alliot Group gives us the competence to engage advisors representing various jurisdictions. We are also active members of the International Bar Association and the International Fiscal Association.
# ALTO - More than advisors
# Bitwy Warszawskiej
# Business Center
# ul. Bitwy Warszawskiej 1920 r. 7
# 02-366 Warszawa
# tel.: +48 22 652 27 51
# e-mail: alto@altoadvisory.pl
# Contact us
# Membership:
# copyright 2018 ALTO
# All rights reserved
# Newsletter
# | Privacy Policy
# | design by Logotomia
# Website uses cookies files for the purpose of providing services and in accordance with the Privacy Policy.
# You can specify the conditions for their storage or access using the below settings.
# I accept
# I decline
# Privacy Center
# Privacy Settings
# Cookies Policy
